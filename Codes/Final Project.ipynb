# %% [markdown]
# # Checkpoint 1

# %%
# Basic Libraries
import numpy as np
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt # we only need pyplot
sb.set() # set the default Seaborn style for graphics

# %% [markdown]
# # Importing the datasets for each of the 5 EPL seasons - 17/18, 18/19, 19/20, 20/21 and 21/22

# %%
pl18 = pd.read_csv('data/2017-18.csv')
pl18.head()
# Out:
#   Div      Date        HomeTeam      AwayTeam  FTHG  FTAG FTR  HTHG  HTAG HTR  \
# 0  E0  11/08/17         Arsenal     Leicester     4     3   H     2     2   D
# 1  E0  12/08/17        Brighton      Man City     0     2   A     0     0   D
# 2  E0  12/08/17         Chelsea       Burnley     2     3   A     0     3   A
# 3  E0  12/08/17  Crystal Palace  Huddersfield     0     3   A     0     2   A
# 4  E0  12/08/17         Everton         Stoke     1     0   H     1     0   H
#
#    ... BbAv<2.5  BbAH  BbAHh  BbMxAHH  BbAvAHH  BbMxAHA  BbAvAHA   PSCH  PSCD  \
# 0  ...     2.32    21  -1.00     1.91     1.85     2.10     2.02   1.49  4.73
# 1  ...     2.27    20   1.50     1.95     1.91     2.01     1.96  11.75  6.15
# 2  ...     2.23    20  -1.75     2.03     1.97     1.95     1.90   1.33  5.40
# 3  ...     1.72    18  -0.75     2.10     2.05     1.86     1.83   1.79  3.56
# 4  ...     1.76    19  -0.75     1.94     1.90     2.01     1.98   1.82  3.49
#
#     PSCA
# 0   7.25
# ...

# %%
pl19 = pd.read_csv('data/2018-19.csv')
pl19.head()
# Out:
#   Div      Date      HomeTeam        AwayTeam  FTHG  FTAG FTR  HTHG  HTAG HTR  \
# 0  E0  10/08/18    Man United       Leicester     2     1   H     1     0   H
# 1  E0  11/08/18   Bournemouth         Cardiff     2     0   H     1     0   H
# 2  E0  11/08/18        Fulham  Crystal Palace     0     2   A     0     1   A
# 3  E0  11/08/18  Huddersfield         Chelsea     0     3   A     0     2   A
# 4  E0  11/08/18     Newcastle       Tottenham     1     2   A     1     2   A
#
#    ... BbAv<2.5  BbAH  BbAHh  BbMxAHH  BbAvAHH  BbMxAHA  BbAvAHA  PSCH  PSCD  \
# 0  ...     1.79    17  -0.75     1.75     1.70     2.29     2.21  1.55  4.07
# 1  ...     1.83    20  -0.75     2.20     2.13     1.80     1.75  1.88  3.61
# 2  ...     1.87    22  -0.25     2.18     2.11     1.81     1.77  2.62  3.38
# 3  ...     1.84    23   1.00     1.84     1.80     2.13     2.06  7.24  3.95
# 4  ...     1.81    20   0.25     2.20     2.12     1.80     1.76  4.74  3.53
#
#    PSCA
# 0  7.69
# 1  4.70
# ...

# %%
pl20 = pd.read_csv('data/2019-20.csv')
pl20.head()
# Out:
#   Div        Date   Time        HomeTeam          AwayTeam  FTHG  FTAG FTR  \
# 0  E0  09/08/2019  20:00       Liverpool           Norwich     4     1   H
# 1  E0  10/08/2019  12:30        West Ham          Man City     0     5   A
# 2  E0  10/08/2019  15:00     Bournemouth  Sheffield United     1     1   D
# 3  E0  10/08/2019  15:00         Burnley       Southampton     3     0   H
# 4  E0  10/08/2019  15:00  Crystal Palace           Everton     0     0   D
#
#    HTHG  HTAG  ... AvgC<2.5  AHCh  B365CAHH  B365CAHA  PCAHH  PCAHA  MaxCAHH  \
# 0     4     0  ...     3.43 -2.25      1.91      1.99   1.94   1.98     1.99
# 1     0     1  ...     2.91  1.75      1.95      1.95   1.96   1.97     2.07
# 2     0     0  ...     1.92 -0.50      1.95      1.95   1.98   1.95     2.00
# 3     0     0  ...     1.71  0.00      1.87      2.03   1.89   2.03     1.90
# 4     0     0  ...     1.71  0.25      1.82      2.08   1.97   1.96     2.03
#
#    MaxCAHA  AvgCAHH  AvgCAHA
# ...

# %%
pl21 = pd.read_csv('data/2020-2021.csv')
pl21.head()
# Out:
#   Div        Date   Time        HomeTeam     AwayTeam  FTHG  FTAG FTR  HTHG  \
# 0  E0  12/09/2020  12:30          Fulham      Arsenal     0     3   A     0
# 1  E0  12/09/2020  15:00  Crystal Palace  Southampton     1     0   H     1
# 2  E0  12/09/2020  17:30       Liverpool        Leeds     4     3   H     3
# 3  E0  12/09/2020  20:00        West Ham    Newcastle     0     2   A     0
# 4  E0  13/09/2020  14:00       West Brom    Leicester     0     3   A     0
#
#    HTAG  ... AvgC<2.5  AHCh  B365CAHH  B365CAHA  PCAHH  PCAHA  MaxCAHH  \
# 0     1  ...     1.84  0.75      2.01      1.89   2.02   1.91     2.13
# 1     0  ...     1.70  0.25      1.78      2.13   1.79   2.17     1.85
# 2     2  ...     2.62 -1.50      1.85      2.05   1.85   2.08     1.90
# 3     0  ...     1.92 -0.50      2.03      1.87   2.04   1.88     2.09
# 4     0  ...     1.73  0.25      1.92      1.98   1.93   1.99     1.95
#
#    MaxCAHA  AvgCAHH  AvgCAHA
# 0     1.92     2.02     1.87
# ...

# %%
pl22 = pd.read_csv('data/2021-2022.csv')
pl22.head()
# Out:
#   Div        Date   Time    HomeTeam        AwayTeam  FTHG  FTAG FTR  HTHG  \
# 0  E0  13/08/2021  20:00   Brentford         Arsenal     2     0   H     1
# 1  E0  14/08/2021  12:30  Man United           Leeds     5     1   H     1
# 2  E0  14/08/2021  15:00     Burnley        Brighton     1     2   A     1
# 3  E0  14/08/2021  15:00     Chelsea  Crystal Palace     3     0   H     2
# 4  E0  14/08/2021  15:00     Everton     Southampton     3     1   H     0
#
#    HTAG  ... AvgC<2.5  AHCh  B365CAHH  B365CAHA  PCAHH  PCAHA  MaxCAHH  \
# 0     0  ...     1.62  0.50      1.75      2.05   1.81   2.13     2.05
# 1     0  ...     2.25 -1.00      2.05      1.75   2.17   1.77     2.19
# 2     0  ...     1.62  0.25      1.79      2.15   1.81   2.14     1.82
# 3     0  ...     1.94 -1.50      2.05      1.75   2.12   1.81     2.16
# 4     1  ...     1.67 -0.50      2.05      1.88   2.05   1.88     2.08
#
#    MaxCAHA  AvgCAHH  AvgCAHA
# 0     2.17     1.80     2.09
# ...

# %% [markdown]
# # Cleaning and preparing data
# We concatenated the 5 datasets to form one final dataset named 'merged' and cleaned the dataset by extracting the relevant columns to form our final dataset, 'final' - "Date","Referee","HomeTeam","AwayTeam","FTHG","FTAG","FTR","HTHG","HTAG","HTR","HS","AS","HST","AST","HC","AC","HF","AF", "HR", "AR", "HY" and "AY"

# %%
merged = pd.concat([pl18, pl19, pl20, pl21, pl22], ignore_index=False,sort=True)

merged.head()
# Out:
#    AC  AF  AHCh  AHh  AR  AS  AST  AY  Avg<2.5  Avg>2.5  ...  VCCD  VCCH  \
# 0   4  12   NaN  NaN   0   6    3   1      NaN      NaN  ...   NaN   NaN
# 1  10   9   NaN  NaN   0  14    4   2      NaN      NaN  ...   NaN   NaN
# 2   5  11   NaN  NaN   0  10    5   3      NaN      NaN  ...   NaN   NaN
# 3   9  19   NaN  NaN   0   8    6   3      NaN      NaN  ...   NaN   NaN
# 4   7  10   NaN  NaN   0   9    1   1      NaN      NaN  ...   NaN   NaN
#
#     VCD    VCH    WHA  WHCA  WHCD  WHCH  WHD    WHH
# 0  4.50   1.53   6.00   NaN   NaN   NaN  4.2   1.53
# 1  5.50  10.00   1.33   NaN   NaN   NaN  4.8  10.00
# 2  6.25   1.25  13.00   NaN   NaN   NaN  5.5   1.25
# 3  3.60   1.83   5.00   NaN   NaN   NaN  3.3   1.80
# 4  3.80   1.70   5.50   NaN   NaN   NaN  3.5   1.70
#
# [5 rows x 127 columns]

# %%
final = pd.DataFrame(merged[["Date", "Referee", "HomeTeam", "AwayTeam","FTHG", "FTAG","FTR","HTHG","HTAG","HTR","HS","AS","HST","AST","HC","AC","HF","AF", "HR", "AR", "HY", "AY"]])
final
# Out:
#            Date      Referee        HomeTeam      AwayTeam  FTHG  FTAG FTR  \
# 0      11/08/17       M Dean         Arsenal     Leicester     4     3   H
# 1      12/08/17     M Oliver        Brighton      Man City     0     2   A
# 2      12/08/17     C Pawson         Chelsea       Burnley     2     3   A
# 3      12/08/17       J Moss  Crystal Palace  Huddersfield     0     3   A
# 4      12/08/17  N Swarbrick         Everton         Stoke     1     0   H
# ..          ...          ...             ...           ...   ...   ...  ..
# 375  22/05/2022   M Atkinson  Crystal Palace    Man United     1     0   H
# 376  22/05/2022       J Moss       Leicester   Southampton     4     1   H
# 377  22/05/2022     A Taylor       Liverpool        Wolves     3     1   H
# 378  22/05/2022     M Oliver        Man City   Aston Villa     3     2   H
# 379  22/05/2022   C Kavanagh         Norwich     Tottenham     0     5   A
#
#      HTHG  HTAG HTR  ...  HST  AST  HC  AC  HF  AF  HR  AR  HY  AY
# ...

# %% [markdown]
# # Checkpoint 2

# %% [markdown]
# ### Problem Formulation 1

# %% [markdown]
# "To predict the amount of goals that will be scored based on various variables such as Shots etc."

# %% [markdown]
# #### Exploratory Data Analysis:

# %%
final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1560 entries, 0 to 379
# Data columns (total 22 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Date      1560 non-null   object
#  1   Referee   1560 non-null   object
#  2   HomeTeam  1560 non-null   object
#  3   AwayTeam  1560 non-null   object
#  4   FTHG      1560 non-null   int64
#  5   FTAG      1560 non-null   int64
#  6   FTR       1560 non-null   object
#  7   HTHG      1560 non-null   int64
#  8   HTAG      1560 non-null   int64
#  9   HTR       1560 non-null   object
#  10  HS        1560 non-null   int64
#  11  AS        1560 non-null   int64
#  12  HST       1560 non-null   int64
#  13  AST       1560 non-null   int64
#  14  HC        1560 non-null   int64
#  15  AC        1560 non-null   int64
#  16  HF        1560 non-null   int64
#  17  AF        1560 non-null   int64
#  18  HR        1560 non-null   int64
#  19  AR        1560 non-null   int64
# ...

# %% [markdown]
# #### Explanation of the variables:

# %% [markdown]
# Below is the explanation of the variables used:
#
#
#
# Referee = Match Referee
# Date = Match Date (dd/mm/yy)
# HomeTeam = Home Team
# Away team = Away Team
# FTHG = Full-Time Home Team Goals
# FTAG = Full-Time Away Team Goals
# FTR  = Full-Time Result (H=Home Win, D=Draw, A=Away Win)
# HTHG = Half Time Home Team Goals
# HTAG = Half Time Away Team Goals
# HTR = Half Time Result (H=Home Win, D=Draw, A=Away Win)
# HS = Home Team Shots
# AS = Away Team Shots
# HST = Home Team Shots on Target
# AST = Away Team Shots on Target
# HC = Home Team Corners
# AC = Away Team Corners
# HF = Home Team Fouls Committed
# AF = Away Team Fouls Committed

# %% [markdown]
# We first limit our data analysis to all those from 'Home Team' since the purpose of our problem is too tackle the issue of scoring goals and thus whether the team is playing at "Home" or "Away" does'nt matter in this case. Besides certain variables such as "HR", "AR", "HY" and "AY" are not needed as well, since they refer to the red cards and yellow cards that have been given out during the match and is not within our scope of exploration. And lastly metadata such as "Date", "Referee", "HomeTeam" and "AwayTeam" are removed as well since they are simply miscellaneous information.

# %% [markdown]
# So we begin by selecting all those variables related to those of the home team:

# %%
#Extracting variables that could affect home goals
HomeData = pd.DataFrame(final[["HS", "HST", "HF", "HC", "FTHG", "HTHG"]])
HomeData
# Out:
#      HS  HST  HF  HC  FTHG  HTHG
# 0    27   10   9   9     4     2
# 1     6    2   6   3     0     0
# 2    19    6  16   8     2     0
# 3    14    4   7  12     0     0
# 4     9    4  13   6     1     1
# ..   ..  ...  ..  ..   ...   ...
# 375   6    3  12   3     1     1
# 376  12    6  10   3     4     0
# 377  29    8   6   5     3     1
# 378  24    5   5  13     3     0
# 379   9    0  13   3     0     0
#
# [1560 rows x 6 columns]

# %% [markdown]
# Thus, our final variables that we will be exploring are as follows:

# %%
HomeData.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1560 entries, 0 to 379
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   HS      1560 non-null   int64
#  1   HST     1560 non-null   int64
#  2   HF      1560 non-null   int64
#  3   HC      1560 non-null   int64
#  4   FTHG    1560 non-null   int64
#  5   HTHG    1560 non-null   int64
# dtypes: int64(6)
# memory usage: 85.3 KB

# %%
HomeData.describe()
# Out:
#                 HS          HST           HF           HC         FTHG  \
# count  1560.000000  1560.000000  1560.000000  1560.000000  1560.000000
# mean     13.523077     4.626282    10.491667     5.683974     1.474359
# std       5.656580     2.602501     3.429665     3.028960     1.305972
# min       1.000000     0.000000     0.000000     0.000000     0.000000
# 25%       9.000000     3.000000     8.000000     3.000000     1.000000
# 50%      13.000000     4.000000    10.000000     5.000000     1.000000
# 75%      17.000000     6.000000    13.000000     8.000000     2.000000
# max      35.000000    15.000000    23.000000    18.000000     9.000000
#
#               HTHG
# count  1560.000000
# mean      0.658974
# std       0.831768
# min       0.000000
# 25%       0.000000
# 50%       0.000000
# 75%       1.000000
# max       5.000000

# %% [markdown]
# As seen from the above the variable are all in fact numeric and univariate in nature.

# %% [markdown]
# So lets start with a Correlation Heatmap to see which of these variables are the most Correlated to goals scored.

# %%
f, axes = plt.subplots(1, 1, figsize = (15,15))
sb.heatmap(HomeData.corr(), vmin = -1, vmax = 1, annot = True, fmt = ".2f")
# Out:
# <AxesSubplot:>

# %% [markdown]
# From the above heatmap, "HS" and "HST" are the most correlated to "FTHG" with a r^2 of 0.34 and 0.63 respectively.
#
#
# Thus, we can see that having more shots have a impact on the final score of the match.
#
#
# Now, lets use a box and whiskers plot to check if taking more shots necessarily results in more goals being scored.

# %% [markdown]
# As for "HST":

# %%
HomeGoals = final['FTHG']
HomeShotsOnTarget = final['HST']
jointDF = pd.concat([HomeShotsOnTarget, HomeGoals], axis = 1)
f = plt.figure(figsize=(18, 6))
jointDF.corr()
# Out:
#           HST     FTHG
# HST   1.00000  0.62818
# FTHG  0.62818  1.00000

# %%
HomeShotsOnTarget = final['HST']
jointDF2 = pd.concat([HomeShotsOnTarget, HomeGoals], axis = 1)
f = plt.figure(figsize=(18, 6))
sb.boxplot(x = "HST", y = "FTHG", data = jointDF2, orient = "h")
jointDF2.corr()
# Out:
#           HST     FTHG
# HST   1.00000  0.62818
# FTHG  0.62818  1.00000

# %% [markdown]
# We can see that as the number of "HST" increase, the number of "FTHG" also increase. This is in accordance with the correlation observed above in the heatmap.

# %% [markdown]
# And as for "HS":

# %%
HomeGoals = final['FTHG']
HomeShots = final['HS']
jointDF = pd.concat([HomeShots, HomeGoals], axis = 1)
f = plt.figure(figsize=(18, 6))
# sb.boxplot(x = "HS", y = "FTHG", data = jointDF, orient = "h")
jointDF.corr()
# Out:
#             HS      FTHG
# HS    1.000000  0.341059
# FTHG  0.341059  1.000000

# %%
HomeShots = final['HS']
jointDF2 = pd.concat([HomeShots, HomeGoals], axis = 1)
f = plt.figure(figsize=(18, 6))
sb.boxplot(x = "HS", y = "FTHG", data = jointDF2, orient = "h")
jointDF2.corr()
# Out:
#             HS      FTHG
# HS    1.000000  0.341059
# FTHG  0.341059  1.000000

# %% [markdown]
# Similarly to "HST", "HS" also has an impact on the "FTHG".
#
# So with that lets make use of these variables to predict goals!

# %% [markdown]
# # Check point 3: Model Training
#
# We have selected to use Decision Tree Classifier for our baseline model to predict the number of goals.
# ### Model 1: Decision Tree Classifier (Base line)
# Below is a helper method for training and fitting a Decision Tree Classifier model.

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import confusion_matrix

# %%
def decisionTree(xTrain, xTest, yTrain, yTest,firstTime): 
    dTree = DecisionTreeClassifier()
    dTree.fit(xTrain, yTrain)

    yTrainPred = dTree.predict(xTrain)
    yTestPred = dTree.predict(xTest)

    r2Test = dTree.score(xTest, yTest)
    mseTest = mean_squared_error(yTest, yTestPred)
    if(firstTime == 1):
        print("Decision Tree Classifier:")
        printGraphs(dTree,xTrain, xTest, yTrain, yTest, yTrainPred, yTestPred)
    
    return r2Test, mseTest

# %% [markdown]
# We have selected to use k-Nearest Neighbors and Random Forest for the other 2 models for this prediction.
# ### Model 2: K-Nearest Neighbors Classifier
# K-Nearest Neighbors classificer that uses a majority vote of the nearest neighbors of each point . We have selected to usethe default paramaters for this model. K-Nearest Neighbors helper method.

# %%
def kNeighbors(xTrain, xTest, yTrain, yTest,firstTime): 
    knn = KNeighborsClassifier()
    knn.fit(xTrain, yTrain)

    yTrainPred = knn.predict(xTrain)
    yTestPred = knn.predict(xTest)

    r2Test = knn.score(xTest, yTest)
    mseTest = mean_squared_error(yTest, yTestPred)
    if(firstTime == 1):
        print("K-Nearest Neighbors Classifier:")
        printGraphs(knn,xTrain, xTest, yTrain, yTest, yTrainPred, yTestPred)
    
    return r2Test, mseTest

# %% [markdown]
# ### Model 3: Random Forest Classifier
# Random Forest uses meta estimator that fits a number of decision tree classifiers and uses averaging to improve accuracy and control over-fitting We have choose to have a max depth of 4 for this version of the model. The value 4 was choosen here so that we do not need to wait for a long time before it is done training and fitting.Random forest model helper method.

# %%
def randomForest(xTrain, xTest, yTrain, yTest,firstTime): 
    forest = RandomForestClassifier(max_depth = 4)
    forest.fit(xTrain, yTrain)

    yTrainPred = forest.predict(xTrain)
    yTestPred = forest.predict(xTest)

    r2Test = forest.score(xTest, yTest)
    mseTest = mean_squared_error(yTest, yTestPred)
    if(firstTime == 1):
        print("Random Forest Classifier:")
        printGraphs(forest,xTrain, xTest, yTrain, yTest, yTrainPred, yTestPred)
    
    return r2Test, mseTest

# %% [markdown]
# This is helper method to print the graph

# %%
def printGraphs(model,xTrain, xTest, yTrain, yTest, yTrainPred, yTestPred):
    print("Goodness of Fit of Model \tTrain Dataset")
    print("Classification Accuracy \t:", model.score(xTrain, yTrain))
    print("Mean Squared Error (MSE) \t:", mean_squared_error(yTrain, yTrainPred))
    print()

    print("Goodness of Fit of Model \tTest Dataset")
    print("Classification Accuracy \t:", model.score(xTest, yTest))
    print("Mean Squared Error (MSE) \t:", mean_squared_error(yTest, yTestPred))
    print()

    f, axes = plt.subplots(1, 2, figsize=(24, 12))
    axes[0].scatter(yTrain, yTrainPred, color = "blue")
    axes[0].plot(yTest, yTest, 'w-', linewidth = 1)
    axes[0].set_xlabel("True values of the Response Variable (Train)")
    axes[0].set_ylabel("Predicted values of the Response Variable (Train)")
    axes[1].scatter(yTest, yTestPred, color = "green")
    axes[1].plot(yTest, yTest, 'w-', linewidth = 1)
    axes[1].set_xlabel("True values of the Response Variable (Test)")
    axes[1].set_ylabel("Predicted values of the Response Variable (Test)")
    
    f, axes2 = plt.subplots(1, 2, figsize=(12, 4))
    axes2[0].set_xlabel("True values of the Response Variable (Train)")
    axes2[0].set_ylabel("Predicted values of the Response Variable (Train)")
    axes2[1].set_xlabel("True values of the Response Variable (Train)")
    axes2[1].set_ylabel("Predicted values of the Response Variable (Train)")
    sb.heatmap(confusion_matrix(yTrain, yTrainPred),
               annot = True, fmt=".0f", annot_kws={"size": 18}, ax = axes2[0])
    sb.heatmap(confusion_matrix(yTest, yTestPred), 
               annot = True, fmt=".0f", annot_kws={"size": 18}, ax = axes2[1])
    plt.show()

# %% [markdown]
# #### Predictors
# Below are the predictors column

# %%
predictors = HomeData.drop(columns="FTHG")
response = HomeData["FTHG"]

predictors
# Out:
#      HS  HST  HF  HC  HTHG
# 0    27   10   9   9     2
# 1     6    2   6   3     0
# 2    19    6  16   8     0
# 3    14    4   7  12     0
# 4     9    4  13   6     1
# ..   ..  ...  ..  ..   ...
# 375   6    3  12   3     1
# 376  12    6  10   3     0
# 377  29    8   6   5     1
# 378  24    5   5  13     0
# 379   9    0  13   3     0
#
# [1560 rows x 5 columns]

# %% [markdown]
# #### Response
# And below is the reponse

# %%
response
# Out:
# 0      4
# 1      0
# 2      2
# 3      0
# 4      1
#       ..
# 375    1
# 376    4
# 377    3
# 378    3
# 379    0
# Name: FTHG, Length: 1560, dtype: int64

# %% [markdown]
# ### Training and Fitting
# Now we will be using the helper model methods we will be train and fitting the models over 100 times to get a more consistent result on the Accuracy Score and MSE value. Each time we will split the data up, train and fit returning the Accuracy Score and MSE values. We will only print the graph once to show how the graph will look like. Printing the graph 100 times is hard to see and understand. All 3 models will use the same dataset.

# %%
i = 1
dTreeAScore = 0
dTreeMse = 0
knnAScore = 0
knnMse = 0
forestAScore = 0
forestMse = 0
while(i != 100):
    xTrain, xTest, yTrain, yTest = train_test_split(predictors, response, test_size = 0.20)
    dTreeResult = decisionTree(xTrain, xTest, yTrain, yTest,i)
    dTreeAScore += dTreeResult[0]
    dTreeMse += dTreeResult[1]
    knnResult = kNeighbors(xTrain, xTest, yTrain, yTest,i)
    knnAScore += knnResult[0]
    knnMse += knnResult[1]
    forestResult = randomForest(xTrain, xTest, yTrain, yTest,i)
    forestAScore += forestResult[0]
    forestMse += forestResult[1]
    i+=1
# Out:
# Decision Tree Classifier:
# Goodness of Fit of Model 	Train Dataset
# Classification Accuracy 	: 0.9855769230769231
# Mean Squared Error (MSE) 	: 0.016826923076923076
#
# Goodness of Fit of Model 	Test Dataset
# Classification Accuracy 	: 0.4519230769230769
# Mean Squared Error (MSE) 	: 1.2532051282051282
# C:\School\Y1S2\Data Science and AI\Anaconda\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# ...

# %%
print("Average of Linear Regression (over 100 times) Accuracy Score:",dTreeAScore/i," MSE:",dTreeMse/i)
print("Average of k-Nearest-Neighbors (over 100 times) Accuracy Score:",knnAScore/i," MSE:",knnMse/i)
print("Average of Random Forest (over 100 times) Accuracy Score:",forestAScore/i," MSE:",forestMse/i)
# Out:
# Average of Linear Regression (over 100 times) Accuracy Score: 0.4134615384615385  MSE: 1.2759935897435897
# Average of k-Nearest-Neighbors (over 100 times) Accuracy Score: 0.3941025641025641  MSE: 1.3841025641025644
# Average of Random Forest (over 100 times) Accuracy Score: 0.4966025641025642  MSE: 0.9815384615384615

# %% [markdown]
# ### Result
# From the value above, we can see that random forest have the highest Accuracy Score and the lowest Mean Squared Error. Therefore we will selecting Random Forest for the model and further tuning its hyperparameter

# %% [markdown]
# # Check Mark 4: Hyperparameter Tuning
# We choose to use Grid Search to tune our parameters and the confusion matrix to evaluate the performance together with the use of the Accuracy Score and MSE.

# %%
forest = RandomForestClassifier(max_depth = 4)
forest.fit(xTrain, yTrain)

yTrainPred = forest.predict(xTrain)
yTestPred = forest.predict(xTest)

r2Test = forest.score(xTest, yTest)
mseTest = mean_squared_error(yTest, yTestPred)
printGraphs(forest,xTrain, xTest, yTrain, yTest, yTrainPred, yTestPred)
# Out:
# Goodness of Fit of Model 	Train Dataset
# Classification Accuracy 	: 0.5344551282051282
# Mean Squared Error (MSE) 	: 1.0080128205128205
#
# Goodness of Fit of Model 	Test Dataset
# Classification Accuracy 	: 0.5512820512820513
# Mean Squared Error (MSE) 	: 0.8173076923076923

# %% [markdown]
# ### Performance Tuning
# We used the grid search to improve the parameter of the random tree classifier. We will be improving the n_estimators, max_depth and the max_leaf_nodes. We first get the n_estimators then we get the max_depth and the max_leaf_nodes

# %%
xTrain, xTest, yTrain, yTest = train_test_split(predictors, response, test_size = 0.20)
gridSearch = GridSearchCV(RandomForestClassifier(),
                           param_grid={"n_estimators":range(50,501,10)})
gridSearch.fit(xTrain, yTrain)
print(gridSearch.best_estimator_)
# Out:
# C:\School\Y1S2\Data Science and AI\Anaconda\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# RandomForestClassifier(n_estimators=70)

# %% [markdown]
# #### Graph for n_estimators
# Below is the graph to show the different values of n_estimator used. The values given in the tuning starts from 50 to 501 and increment by 10 each time

# %%
graphEstiators=sb.lineplot(x=range(50,501,10), y=gridSearch.cv_results_["mean_test_score"])
graphEstiators.set_title(f'Best number of n_estimators at {range(50,501,10)[gridSearch.best_index_]}', size=15);
estimator = range(50,501,10)[gridSearch.best_index_]

# %% [markdown]
# #### Max Depth and Max Leaf Node
# For both the max_depth and the max_leaf_nodes the values we used is starts from 3 to 9. We also use back the value of n_estimator that we found before in this tuning.

# %%
gridSearch2 = GridSearchCV(RandomForestClassifier(),
                           param_grid={"n_estimators":[estimator],"max_depth":range(3,10),"max_leaf_nodes":range(3,10)})
gridSearch2.fit(xTrain, yTrain)
print(gridSearch2.best_estimator_)
# Out:
# C:\School\Y1S2\Data Science and AI\Anaconda\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# RandomForestClassifier(max_depth=5, max_leaf_nodes=8, n_estimators=70)

# %% [markdown]
# Here we are converting the result from the gridSearch into a a dataframe for graph plotting

# %%
i = 3
j = 3
counter = 0;
listColumn = []
while(i<10):
    j=3
    while(j<10):
        column = [None]*3
        column[0] = i
        column[1] = j
        column[2] = gridSearch2.cv_results_["mean_test_score"][counter]
        j+=1
        listColumn.append(column)
        counter+=1
    i+=1
dfResult = pd.DataFrame(listColumn, columns=["max_depth","max_leaf_nodes","score"])

# %% [markdown]
# ### Graph for Max Depth and Max Leaf node
# Here we are plotting the graph of to show different result of the parameters

# %%
depth = listColumn[gridSearch2.best_index_][0]
maxLeafNode = listColumn[gridSearch2.best_index_][1]

graphDepthLeaf=sb.lineplot(x="max_depth", y="score",hue="max_leaf_nodes", data = dfResult, palette = "tab10")
graphDepthLeaf.set_title(f'Best max depth is {depth} and max leaf node is {maxLeafNode}', size=15);
graphDepthLeaf.legend(loc='upper right')

# %% [markdown]
# ### New Random Forest Classifier with tuned values

# %%
def randomForestWithTuned(xTrain, xTest, yTrain, yTest,firstTime): 
    forest = RandomForestClassifier(max_depth = depth, max_leaf_nodes = maxLeafNode, n_estimators = estimator)
    forest.fit(xTrain, yTrain)

    yTrainPred = forest.predict(xTrain)
    yTestPred = forest.predict(xTest)

    r2Test = forest.score(xTest, yTest)
    mseTest = mean_squared_error(yTest, yTestPred)
    if(firstTime == 1):
        print("Random Forest Classifier with tuned values:")
        printGraphs(forest,xTrain, xTest, yTrain, yTest, yTrainPred, yTestPred)
    
    return r2Test, mseTest

# %%
i = 1
dTreeAScore = 0
dTreeMse = 0
forestTunedAScore = 0
forestTunedMse = 0
while(i != 100):
    xTrain, xTest, yTrain, yTest = train_test_split(predictors, response, test_size = 0.20)
    dTreeResult = decisionTree(xTrain, xTest, yTrain, yTest,i)
    dTreeAScore += dTreeResult[0]
    dTreeMse += dTreeResult[1]
    forestTunedResult = randomForestWithTuned(xTrain, xTest, yTrain, yTest,i)
    forestTunedAScore += forestTunedResult[0]
    forestTunedMse += forestResult[1]
    i+=1
# Out:
# Decision Tree Classifier:
# Goodness of Fit of Model 	Train Dataset
# Classification Accuracy 	: 0.9879807692307693
# Mean Squared Error (MSE) 	: 0.016826923076923076
#
# Goodness of Fit of Model 	Test Dataset
# Classification Accuracy 	: 0.47115384615384615
# Mean Squared Error (MSE) 	: 1.3846153846153846
# Random Forest Classifier with tuned values:
# Goodness of Fit of Model 	Train Dataset
# Classification Accuracy 	: 0.5336538461538461
# Mean Squared Error (MSE) 	: 0.9046474358974359
#
# Goodness of Fit of Model 	Test Dataset
# Classification Accuracy 	: 0.4775641025641026
# Mean Squared Error (MSE) 	: 1.141025641025641

# %%
print("Average of Decision Tree (baseline) (over 100 times) Accuracy Score:",dTreeAScore/i," MSE:",dTreeMse/i)
print("Average of Random Forest Tuned (over 100 times) Accuracy Score:",forestTunedAScore/i," MSE:",forestTunedMse/i)
# Out:
# Average of Decision Tree (baseline) (over 100 times) Accuracy Score: 0.41275641025641036  MSE: 1.2846794871794867
# Average of Random Forest Tuned (over 100 times) Accuracy Score: 0.49134615384615365  MSE: 0.8376923076923064

# %% [markdown]
# ### Summary
# With the newly tuned hyperparameters, the Accuracy Score increased by a small amount comparing to the original random forest classifier, and it is performing better compared to the base line model

# %% [markdown]
# # Check point 5: Conclusion
# #### Briefly summarize your findings in Experiments.
# In order to predict the number of goals scored, we have used the classifier to train and predict the goals scored. We use the Accuracy Score and MSE (mean squared error) to determine how effective and accurate the model is. We used decision tree classifier as the base line. The model we ended up choosing is the random tree classifier as it has the higest Accuracy Score and the lowest MSE out of the 3 models trained. We then tuned the hyperparameter to improve the accuracy of the model in the prediction.

# %%
merged2 = pd.concat([pl18, pl19, pl20, pl21, pl22], ignore_index=False, keys=['17/18','18/19','19/20','20/21','21/22'],sort=True)
merged2.head()
# Out:
#          AC  AF  AHCh  AHh  AR  AS  AST  AY  Avg<2.5  Avg>2.5  ...  VCCD  \
# 17/18 0   4  12   NaN  NaN   0   6    3   1      NaN      NaN  ...   NaN
#       1  10   9   NaN  NaN   0  14    4   2      NaN      NaN  ...   NaN
#       2   5  11   NaN  NaN   0  10    5   3      NaN      NaN  ...   NaN
#       3   9  19   NaN  NaN   0   8    6   3      NaN      NaN  ...   NaN
#       4   7  10   NaN  NaN   0   9    1   1      NaN      NaN  ...   NaN
#
#          VCCH   VCD    VCH    WHA  WHCA  WHCD  WHCH  WHD    WHH
# 17/18 0   NaN  4.50   1.53   6.00   NaN   NaN   NaN  4.2   1.53
#       1   NaN  5.50  10.00   1.33   NaN   NaN   NaN  4.8  10.00
#       2   NaN  6.25   1.25  13.00   NaN   NaN   NaN  5.5   1.25
#       3   NaN  3.60   1.83   5.00   NaN   NaN   NaN  3.3   1.80
#       4   NaN  3.80   1.70   5.50   NaN   NaN   NaN  3.5   1.70
#
# [5 rows x 127 columns]

# %%
concl = pd.DataFrame(merged2[["HomeTeam","AwayTeam","FTHG", "FTAG","FTR","HTHG","HTAG","HTR","HS","AS","HST","AST","HC","AC","HF","AF"]])
concl
# Out:
#                  HomeTeam      AwayTeam  FTHG  FTAG FTR  HTHG  HTAG HTR  HS  \
# 17/18 0           Arsenal     Leicester     4     3   H     2     2   D  27
#       1          Brighton      Man City     0     2   A     0     0   D   6
#       2           Chelsea       Burnley     2     3   A     0     3   A  19
#       3    Crystal Palace  Huddersfield     0     3   A     0     2   A  14
#       4           Everton         Stoke     1     0   H     1     0   H   9
# ...                   ...           ...   ...   ...  ..   ...   ...  ..  ..
# 21/22 375  Crystal Palace    Man United     1     0   H     1     0   H   6
#       376       Leicester   Southampton     4     1   H     0     0   D  12
#       377       Liverpool        Wolves     3     1   H     1     1   D  29
#       378        Man City   Aston Villa     3     2   H     0     1   A  24
#       379         Norwich     Tottenham     0     5   A     0     2   A   9
#
#            AS  HST  AST  HC  AC  HF  AF
# ...

# %%
teams = list(concl.loc['17/18']['HomeTeam'].unique())
teamdata = {team:concl[np.logical_or(concl["HomeTeam"]==team, concl["AwayTeam"]==team)] for team in teams}

# %%
teams
# Out:
# ['Arsenal',
#  'Brighton',
#  'Chelsea',
#  'Crystal Palace',
#  'Everton',
#  'Southampton',
#  'Watford',
#  'West Brom',
#  'Man United',
#  'Newcastle',
#  'Bournemouth',
#  'Burnley',
#  'Leicester',
#  'Liverpool',
#  'Stoke',
#  'Swansea',
#  'Huddersfield',
#  'Tottenham',
#  'Man City',
#  'West Ham']

# %%
seasons = ['17/18','18/19','19/20','20/21','21/22']
teams = ['Man City', 'Crystal Palace']
teamgoals = {}
avg_goals = {}
avg_shots = {}  # added new dictionary for average shots
for team in teams:
    for season in seasons:
        matches_played = len(teamdata[team].loc[teamdata[team].index.get_level_values(0) == season].loc[(teamdata[team]["HomeTeam"] == team) | (teamdata[team]["AwayTeam"] == team)])
        goals_scored = teamdata[team].loc[teamdata[team].index.get_level_values(0).str.contains(season)].loc[teamdata[team]["HomeTeam"] == team, 'FTHG'].sum() + teamdata[team].loc[teamdata[team].index.get_level_values(0).str.contains(season)].loc[teamdata[team]["AwayTeam"] == team, 'FTAG'].sum()
        teamgoals[season + " " + team] = goals_scored
        shots_on_target = teamdata[team].loc[teamdata[team].index.get_level_values(0) == season][['HST', 'AST']].sum().sum()
        avg_shots[season + " " + team] = shots_on_target / matches_played  # calculate average shots per match
        avg_goals[season + " " + team] = goals_scored / matches_played

# %%
fig, ax1 = plt.subplots(figsize=(12, 6))

# plot the first bar chart
ax1.bar(x=[i-0.2 for i in range(len(avg_shots))], height=avg_shots.values(), width=0.4, label='Average Shots on Target per Match')

# plot the second bar chart
ax2 = ax1.twinx()
ax2.bar(x=[i+0.2 for i in range(len(avg_goals))], height=avg_goals.values(), width=0.4, color='orange', label='Average Goals Scored per Match')

# set the x-axis labels
ax1.set_xticks(range(len(avg_shots)))
ax1.set_xticklabels(avg_shots.keys(), rotation=45, ha='right')

# set the y-axis labels and scales
ax1.set_ylabel('Average Shots on Target per Match')
ax2.set_ylabel('Average Goals Scored per Match')
ax1.set_ylim(0, max(avg_shots.values())*1.2)
ax2.set_ylim(0, max(avg_goals.values())*1.2)

# set the chart title and legend
ax1.set_title('Average Shots on Target and Average Goals Scored by Team by Season')
ax1.legend(loc='upper left')
ax2.legend(loc='upper right')

plt.show()

# %% [markdown]
# As seen from the "Shots on Target & Goals Scored"
# graph above, we can see how, generally, more shots on target translates to more goals scored. However, better teams such as Manchester City are able to convert these shots on target to actual goals more often. Teams should thus not only aim to maximise shots on target by creating chances, but players should be able to efficiently and consistently convert these opportunities in matches to score.

# %% [markdown]
# #### The limitation of your current model. How you can improve your model.
# The current limitation of our model is that the hyperparameter is tuned 1 at a time. This can cause some inaccuracy in the tuning. However if we were to use the same values and tuned at the same time, the time required will increase by a huge amount as there will be around 2205 combination to fit.

# %% [markdown]
# ###                                       ---------------------------------------------------------------------------- END -------------------------------------------------------------------------------
